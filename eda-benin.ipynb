# %%
import pandas as pd

# Load dataset with correct filename
df = pd.read_csv("data/benin_utf8.csv", encoding="utf-8")

# Show the first few rows to confirm it's loaded correctly
df.head()
# Out:
# ` 苡Ȏ 苡Ȏ \t陌统 䏟  祚祹Ϧ     Ȏ 殗陌统 쿚䏟Ü 㻀ﳇ翿 Ͽ       쇈苪Ȏ     쿘䏟Ü  Ȏ 㺰謧Ȏ ↠苫Ȏ ⫰苫Ȏ    쯠䏟Ü ㋐ﳂ翿 譹  \
# 0                                         쿚䏟Ü 침䏟Ü
# 1               ﲹ翿     勨苤Ȏ 櫸謫Ȏ ꍐ謙Ȏ 홐譿Ȏ 㳘謪Ȏ     ...
# 2                                         쿚䏟Ü 침䏟Ü
# 3
#
#                                         Unnamed: 1  \
# 0                                              NaN
# 1     业਱翸 ⼸苫Ȏ 䶐謨Ȏ 큰਴翸 䐐਺翸 +        譿Ȏ   Ü   Ȏ 䫐謨Ȏ
# 2                                              NaN
# 3                                              NaN
#
#                             Unnamed: 2  \
# 0                                  NaN
# 1     ⩰譳Ȏ 䫐謨Ȏ  譿Ȏ 糘苞Ȏ ⼸苫Ȏ 폰謐Ȏ 䌎਱翸   Ȏ
# 2                                  NaN
# 3                                  NaN
#
#                                           Unnamed: 3
# 0                                                NaN
# 1         䫐謨Ȏ         洘謪Ȏ ︮਱翸 폈謐Ȏ 糘苞Ȏ    ῐ苮Ȏ 폈謐Ȏ...
# 2                                                NaN
# ...

# %%
df.describe()  # Show summary stats for numeric columns
# Out:
# ` 苡Ȏ 苡Ȏ \t陌统 䏟  祚祹Ϧ     Ȏ 殗陌统 쿚䏟Ü 㻀ﳇ翿 Ͽ       쇈苪Ȏ     쿘䏟Ü  Ȏ 㺰謧Ȏ ↠苫Ȏ ⫰苫Ȏ    쯠䏟Ü ㋐ﳂ翿 譹  \
# count                                                   4
# unique                                                  3
# top                                            쿚䏟Ü 침䏟Ü
# freq                                                    2
#
#                                              Unnamed: 1  \
# count                                                 1
# unique                                                1
# top        业਱翸 ⼸苫Ȏ 䶐謨Ȏ 큰਴翸 䐐਺翸 +        譿Ȏ   Ü   Ȏ 䫐謨Ȏ
# freq                                                  1
#
#                                  Unnamed: 2  \
# count                                     1
# unique                                    1
# top        ⩰譳Ȏ 䫐謨Ȏ  譿Ȏ 糘苞Ȏ ⼸苫Ȏ 폰謐Ȏ 䌎਱翸   Ȏ
# freq                                      1
#
#                                                Unnamed: 3
# count                                                   1
# ...

# %%
df.isna().sum()  # Count missing values per column
# Out:
# ` 苡Ȏ 苡Ȏ \t陌统 䏟  祚祹Ϧ     Ȏ 殗陌统 쿚䏟Ü 㻀ﳇ翿 Ͽ       쇈苪Ȏ     쿘䏟Ü  Ȏ 㺰謧Ȏ ↠苫Ȏ ⫰苫Ȏ    쯠䏟Ü ㋐ﳂ翿 譹    0
# Unnamed: 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               3
# ...
